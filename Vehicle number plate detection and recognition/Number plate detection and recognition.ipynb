# %% [markdown]
# #Downloading YOLOv8 model from github

# %%
# !git clone https://github.com/kalaiyarasan1264/Yolo-model-for-number-plate-detection.git
# Out:
# Cloning into 'Yolo-model-for-number-plate-detection'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 124 (delta 21), reused 122 (delta 20), pack-reused 0
# Receiving objects: 100% (124/124), 3.59 MiB | 25.35 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# #Importing required libraries and dependencies

# %%
from IPython.display import Image

# %%
# %cd /content/Yolo-model-for-number-plate-detection
# Out:
# /content/Yolo-model-for-number-plate-detection

# %%
# !pip install -e '.[dev]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/Yolo-model-for-number-plate-detection
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 KB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 KB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 57.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 61.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.4 MB/s eta 0:00:00
# ...

# %%
# %cd /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect
# Out:
# /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect

# %% [markdown]
# #Importing the sample video

# %%
# !gdown "https://drive.google.com/uc?id=1P-oVR0J35Dw40lzw47sE19oADSW-tyb1&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1P-oVR0J35Dw40lzw47sE19oADSW-tyb1&confirm=t
# To: /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4
# 100% 9.56M/9.56M [00:00<00:00, 213MB/s]

# %% [markdown]
# #Detecting the number plate in the vehicles

# %%
# !python predict.py model='best.pt' source='demo.mp4'
# Out:
# Ultralytics YOLOv8.0.3 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# video 1/1 (1/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 29.1ms
# video 1/1 (2/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 28.3ms
# video 1/1 (3/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 1 licence, 28.2ms
# video 1/1 (4/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 28.2ms
# video 1/1 (5/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 28.3ms
# video 1/1 (6/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 28.2ms
# ...

# %% [markdown]
# ![Number plate detection.png](data:image/png;base64,...)

# %% [markdown]
# #Downloading EasyOCR python module

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 47.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.2/608.2 KB 48.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 16.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# ...

# %% [markdown]
# #Detection and recognition of the number plate of vehicles

# %%
# !python predict.py model='best.pt' source='demo.mp4'
# Out:
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteDownloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteUltralytics YOLOv8.0.3 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# video 1/1 (1/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 29.0ms
# video 1/1 (2/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 28.2ms
# video 1/1 (3/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 1 licence, 28.2ms
# video 1/1 (4/631) /content/Yolo-model-for-number-plate-detection/ultralytics/yolo/v8/detect/demo.mp4: 416x640 2 licences, 28.2ms
# ...

# %% [markdown]
# ![Number plate detection and recognition.png](data:image/png;base64,...)

# %% [markdown]
# #For detection in live video

# %%
# !python predict.py model='best.pt' source=0
